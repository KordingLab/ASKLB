# %%
import ipywidgets as widgets
from google.colab import files
from IPython.display import clear_output

test_button = widgets.Button(description="test upload button")

def on_button_clicked(b):
    clear_output(wait=True)
    result = files.upload()
    display(b)
    return result

test_button.on_click(on_button_clicked)
#display(test_button)

# %%
from widget import ASKLBWidget

ASKLBWidget()
# Out:
# ASKLBWidget(children=(HBox(children=(Label(value='Run time (min):'), IntSlider(value=1, max=60, min=1))), HBox…
#      <input type="file" id="files-5fd4e085-73a6-45ac-b7dd-950a5ace7ed6" name="files[]" multiple disabled />
#      <output id="result-5fd4e085-73a6-45ac-b7dd-950a5ace7ed6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
import pandas as pd

test = pd.read_csv("../MetaData/80003.csv", dtype='unicode')

# %%
test.head()
# Out:
#              Label non cancer non cancer.1 non cancer.2 non cancer.3  \
# 0  ENSG00000000419         12            0           72            8
# 1  ENSG00000000938        116           25           56           13
# 2  ENSG00000001036         68           19           21           17
# 3  ENSG00000001461         75           15           29            6
# 4  ENSG00000001629         51           55           45           19
#
#   non cancer.4 non cancer.5 non cancer.6 non cancer.7 non cancer.8  ...  \
# 0           33            2            4           12            5  ...
# 1           23           18           20            9           73  ...
# 2           52           35           25            6           20  ...
# 3           55           12           10            1            7  ...
# 4           37           40           47            2           14  ...
#
#   NSCLC.398 NSCLC.399 non cancer.371 non cancer.372 non cancer.373  \
# 0        16         0              0              0              0
# 1        37        22              2              1             10
# 2        13        33              0              0              0
# 3         5        17              0             21              0
# 4        16        10              2             25              3
#
#   non cancer.374 non cancer.375 non cancer.376 NSCLC.400 NSCLC.401
# 0              0              0              0         0         7
# 1              0             43              0         0         5
# 2              4              0              0         0         1
# 3              0              0              0         0         0
# 4              0              0              0         1         1
#
# [5 rows x 780 columns]
